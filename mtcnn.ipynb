# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd content/gdrive/MyDrive/mtcnn-pytorch-master

# %%
from src.detector import detect_faces
from src.utils import show_bboxes
from PIL import Image

# %%
image = Image.open('images/test4.jpg')
bounding_boxes, landmarks = detect_faces(image)
image = show_bboxes(image, bounding_boxes, landmarks)
image
# Out:
# <PIL.Image.Image image mode=RGB size=1024x547 at 0x7FA0A1E34110>
