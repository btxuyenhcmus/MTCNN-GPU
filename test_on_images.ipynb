# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src import detect_faces, show_bboxes, detect_faces_type1
from PIL import Image

# %%
img = Image.open('images/family.jpeg')

# %%
# %%time
bounding_boxes, landmarks = detect_faces(img)
# Out:
# CPU times: user 549 ms, sys: 637 µs, total: 550 ms
# Wall time: 151 ms
# /home/btxuyen/Documents/learning/MTCNN-GPU/src/get_nets.py:70: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   a = F.softmax(a)
# /home/btxuyen/Documents/learning/MTCNN-GPU/src/detector.py:79: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img_boxes = Variable(torch.FloatTensor(img_boxes), volatile=True)
# /home/btxuyen/Documents/learning/MTCNN-GPU/src/get_nets.py:115: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   a = F.softmax(a)
# /home/btxuyen/Documents/learning/MTCNN-GPU/src/detector.py:100: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img_boxes = Variable(torch.FloatTensor(img_boxes), volatile=True)
# /home/btxuyen/Documents/learning/MTCNN-GPU/src/get_nets.py:168: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   a = F.softmax(a)

# %%
show_bboxes(img, bounding_boxes, landmarks)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7FF6E078A4E0>

# %%
# %%time
bounding_boxes, landmarks = detect_faces_type1(img)
# Out:
# CPU times: user 3.24 s, sys: 4.79 ms, total: 3.24 s
# Wall time: 1.68 s

# %%
show_bboxes(img, bounding_boxes, landmarks)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7FF6E078A6D8>
