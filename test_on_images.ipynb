# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src import detect_faces, show_bboxes, detect_faces_type1, detect_faces_type2,detect_faces_type3
from PIL import Image

# %%
img = Image.open('images/family.jpeg')

# %%
# %%time
bounding_boxes, landmarks = detect_faces_type3(img)
# Out:
# /home/btxuyen/Documents/learning/MTCNN-GPU/src/first_stage.py:32: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img = Variable(torch.FloatTensor(_preprocess(img)), volatile=True)
# /home/btxuyen/Documents/learning/MTCNN-GPU/src/get_nets.py:433: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   a = F.softmax(a)
# /home/btxuyen/Documents/learning/MTCNN-GPU/src/first_stage.py:32: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img = Variable(torch.FloatTensor(_preprocess(img)), volatile=True)
# /home/btxuyen/Documents/learning/MTCNN-GPU/src/detector.py:58: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img_boxes = Variable(torch.FloatTensor(img_boxes), volatile=True)
# /home/btxuyen/Documents/learning/MTCNN-GPU/src/get_nets.py:471: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   a = F.softmax(a)
# /home/btxuyen/Documents/learning/MTCNN-GPU/src/detector.py:79: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img_boxes = Variable(torch.FloatTensor(img_boxes), volatile=True)
# CPU times: user 3.65 s, sys: 649 ms, total: 4.29 s
# Wall time: 2 s
# /home/btxuyen/Documents/learning/MTCNN-GPU/src/get_nets.py:516: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   a = F.softmax(a)

# %%
show_bboxes(img, bounding_boxes, landmarks)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7F64206589B0>

# %%
# %%time
bounding_boxes, landmarks = detect_faces_type1(img)
# Out:
# CPU times: user 3.16 s, sys: 4.22 ms, total: 3.17 s
# Wall time: 1.63 s

# %%
show_bboxes(img, bounding_boxes, landmarks)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7F19A28AE780>

# %%
# %%time
bounding_boxes, landmarks = detect_faces_type2(img)
# Out:
# CPU times: user 5.11 s, sys: 2.05 ms, total: 5.12 s
# Wall time: 736 ms

# %%
show_bboxes(img, bounding_boxes, landmarks)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7F19A5CF1DA0>

# %%
# %%time
bounding_boxes, landmarks = detect_faces_type3(img)
# Out:
# CPU times: user 7.47 s, sys: 12.9 ms, total: 7.49 s
# Wall time: 1.92 s

# %%
show_bboxes(img, bounding_boxes, landmarks)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7F196417B128>
